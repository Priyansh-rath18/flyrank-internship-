# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Priyansh-rath18/flyrank-internship-/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# **Lane:** Ranking declining content for triage.
#
# I'm taking the triage-ranking lane: given many content pages that look like they're declining, which one should a human fix first? FlyRank already flags declines with hand-written rules (health score, quick-win tags); this lane asks whether a learned ranking can beat that rule using the richer signals in the data, rather than replacing human judgment.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# **Decision improved:** which declining page an editor works on next, given limited hours.
#
# **Who acts:** an SEO/content editor who picks items off a triage queue.
#
# **Cost of a wrong call:** if a low-impact page is prioritized, real revenue- or traffic-losing pages keep declining unaddressed (opportunity cost); if the model over-flags noise, editor hours are wasted chasing false alarms instead of real decliners.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %%
rch question and provisional lane

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
# The starter set has 30,000 content rows across 32 clients. 54.2% of rows are tagged `trend_direction == "down"` — over half the pages are already trending down, which is exactly the pool a triage-ranking model would need to sort. Only 4.0% of rows have `avg_position == 0` (the "no data" gotcha, not rank zero), so position data is usable for most of the set. This looks worth the next 7 weeks: there's a large, mostly-populated pool of declining pages to rank, not just a handful of edge cases.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

url = "https://raw.githubusercontent.com/Priyansh-rath18/flyrank-internship-/main/data/raw/content_refresh_anonymized.csv"
df = pd.read_csv(url)

print(df.shape)
print(df.columns.tolist())
print(f"clients: {df['client_id'].nunique()}")
print(df['trend_direction'].value_counts(normalize=True).round(3))
print(f"avg_position==0 (missing) share: {(df['avg_position']==0).mean():.1%}")
# Out:
# (30000, 44)
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']
# clients: 32
# trend_direction
# down      0.542
# stable    0.199
# up        0.146
# new       0.075
# flat      0.038
# Name: proportion, dtype: float64
# avg_position==0 (missing) share: 4.0%

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# **Can say:** what's observed (this page's metrics declined over the trailing window); directional and decision-support signals (this ranking suggests where an editor should look first); measured comparisons against the existing rule-based flags.
#
# **Can't say:** causal proof of why a page declined, or any claim to predict Google's ranking algorithm itself. The target label must come from an observed outcome, not a rule someone already wrote — otherwise the model just learns the rule, not the world.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
